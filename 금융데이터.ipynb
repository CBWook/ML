# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
data = pd.read_csv(r'C:\Users\seven\OneDrive\바탕 화면\경진대회\금융보안원_경진대회_데이터(최종제출).csv')

# %%
data.head()
# Out:
#      기준년월  품목대분류코드   품목대분류명  품목중분류코드   품목중분류명  성별   연령   가구생애주기 고객소재지_광역시도  \
# 0  201903       10       의류     1010     여성의류  여성  40대  초중고자녀가구      서울특별시
# 1  201903       21  e상품/서비스     2110   o2o서비스  여성  20대  신혼영유아가구      서울특별시
# 2  201903       19    출산/육아     1913  육아용품서비스  여성  30대  신혼영유아가구      서울특별시
# 3  201903       21  e상품/서비스     2111  e머니/상품권  여성  30대  신혼영유아가구      서울특별시
# 4  201903       17       생활     1710     생활용품  여성  30대  신혼영유아가구      서울특별시
#
#   고객소재지_시군구 고객소재지_읍면동     매출금액  매출건수
# 0       구로구        궁동   782521    13
# 1       구로구        궁동   963789    29
# 2       구로구        궁동   924309    46
# 3       구로구        궁동  1089360    54
# 4       구로구        궁동  1656740    58

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519297 entries, 0 to 519296
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   기준년월        519297 non-null  int64
#  1   품목대분류코드     519297 non-null  int64
#  2   품목대분류명      519297 non-null  object
#  3   품목중분류코드     519297 non-null  int64
#  4   품목중분류명      519297 non-null  object
#  5   성별          519297 non-null  object
#  6   연령          519297 non-null  object
#  7   가구생애주기      519297 non-null  object
#  8   고객소재지_광역시도  519297 non-null  object
#  9   고객소재지_시군구   519297 non-null  object
#  10  고객소재지_읍면동   519297 non-null  object
#  11  매출금액        519297 non-null  int64
#  12  매출건수        519297 non-null  int64
# dtypes: int64(5), object(8)
# memory usage: 51.5+ MB

# %%
data[['매출금액', '매출건수']].describe()
# Out:
#                매출금액           매출건수
# count  5.192970e+05  519297.000000
# mean   2.188457e+06      48.958860
# std    6.438257e+06     163.855617
# min    1.490000e+03       4.000000
# 25%    3.412650e+05       9.000000
# 50%    7.628000e+05      17.000000
# 75%    1.878443e+06      38.000000
# max    5.918488e+08   11811.000000

# %%
data_df = pd.DataFrame(data)

# %%
data_df
# Out:
#           기준년월  품목대분류코드   품목대분류명  품목중분류코드   품목중분류명  성별      연령   가구생애주기  \
# 0       201903       10       의류     1010     여성의류  여성     40대  초중고자녀가구
# 1       201903       21  e상품/서비스     2110   o2o서비스  여성     20대  신혼영유아가구
# 2       201903       19    출산/육아     1913  육아용품서비스  여성     30대  신혼영유아가구
# 3       201903       21  e상품/서비스     2111  e머니/상품권  여성     30대  신혼영유아가구
# 4       201903       17       생활     1710     생활용품  여성     30대  신혼영유아가구
# ...        ...      ...      ...      ...      ...  ..     ...      ...
# 519292  202103       20   여가/스포츠     2013       여행  여성     30대     1인가구
# 519293  202103       21  e상품/서비스     2110   o2o서비스  남성     30대     1인가구
# 519294  202103       11     패션잡화     1113   시계/주얼리  여성     30대  신혼영유아가구
# 519295  202103       16       식품     1610     가공식품  남성     40대  초중고자녀가구
# 519296  202103       21  e상품/서비스     2110   o2o서비스  여성  60대 이상     노인가구
#
#        고객소재지_광역시도 고객소재지_시군구 고객소재지_읍면동     매출금액  매출건수
# 0           서울특별시       구로구        궁동   782521    13
# 1           서울특별시       구로구        궁동   963789    29
# 2           서울특별시       구로구        궁동   924309    46
# 3           서울특별시       구로구        궁동  1089360    54
# 4           서울특별시       구로구        궁동  1656740    58
# ...           ...       ...       ...      ...   ...
# 519292      서울특별시      영등포구    영등포동7가  1411368     7
# 519293      서울특별시      영등포구    영등포동7가  1386040    63
# 519294      서울특별시      영등포구    영등포동7가   390818     7
# 519295      서울특별시      영등포구    영등포동7가   327592     7
# 519296      서울특별시      영등포구    영등포동8가   926404    10
#
# [519297 rows x 13 columns]

# %%
import seaborn as sns

# %%
data_L_M = data_df[['기준년월','품목대분류명', '매출금액']]
data_L_M
# Out:
#           기준년월   품목대분류명     매출금액
# 0       201903       의류   782521
# 1       201903  e상품/서비스   963789
# 2       201903    출산/육아   924309
# 3       201903  e상품/서비스  1089360
# 4       201903       생활  1656740
# ...        ...      ...      ...
# 519292  202103   여가/스포츠  1411368
# 519293  202103  e상품/서비스  1386040
# 519294  202103     패션잡화   390818
# 519295  202103       식품   327592
# 519296  202103  e상품/서비스   926404
#
# [519297 rows x 3 columns]

# %%
grouped_L_M = data_L_M['매출금액'].groupby(data_L_M['품목대분류명']).sum()
grouped_L_M
# Out:
# 품목대분류명
# e상품/서비스    454175510959
# 가구          12764862337
# 건강          49437651863
# 기타          10129143665
# 뷰티          32518422146
# 생활          58580296181
# 식품         102992355734
# 여가/스포츠     148694701457
# 의류          53199290252
# 인테리어        18813051365
# 전자          92697362599
# 출산/육아       58978618322
# 패션잡화        43478005680
# Name: 매출금액, dtype: int64

# %%
df_g_L_M = pd.DataFrame(grouped_L_M)
df_g_L_M
# Out:
#                  매출금액
# 품목대분류명
# e상품/서비스  454175510959
# 가구        12764862337
# 건강        49437651863
# 기타        10129143665
# 뷰티        32518422146
# 생활        58580296181
# 식품       102992355734
# 여가/스포츠   148694701457
# 의류        53199290252
# 인테리어      18813051365
# 전자        92697362599
# 출산/육아     58978618322
# 패션잡화      43478005680

# %%
df_g_L_M.rename(columns={'매출금액':'매출합계'}, inplace = True)
df_g_L_M.reset_index(inplace=True)
df_g_L_M.rename(columns= {'품목대분류명' : 'largecategory', '매출합계' : 'Total'}, inplace= True)
df_g_L_M
# Out:
#    largecategory         Total
# 0        e상품/서비스  454175510959
# 1             가구   12764862337
# 2             건강   49437651863
# 3             기타   10129143665
# 4             뷰티   32518422146
# 5             생활   58580296181
# 6             식품  102992355734
# 7         여가/스포츠  148694701457
# 8             의류   53199290252
# 9           인테리어   18813051365
# 10            전자   92697362599
# 11         출산/육아   58978618322
# 12          패션잡화   43478005680

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['font.size'] = 23
plt.rcParams['figure.figsize'] = (15, 12)

# %%
sns.barplot(x = 'largecategory', y = 'Total', data = df_g_L_M)
# Out:
# <AxesSubplot:xlabel='largecategory', ylabel='Total'>

# %%
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 519292    True
# 519293    True
# 519294    True
# 519295    True
# 519296    True
# Name: 기준년월, Length: 519297, dtype: bool

# %%
data_L_C = data_df[['품목대분류명', '매출건수']]
data_L_C
# Out:
#          품목대분류명  매출건수
# 0            의류    13
# 1       e상품/서비스    29
# 2         출산/육아    46
# 3       e상품/서비스    54
# 4            생활    58
# ...         ...   ...
# 519292   여가/스포츠     7
# 519293  e상품/서비스    63
# 519294     패션잡화     7
# 519295       식품     7
# 519296  e상품/서비스    10
#
# [519297 rows x 2 columns]

# %%
grouped_L_C = data_L_C['매출건수'].groupby(data_L_C['품목대분류명']).sum()
grouped_L_C
# Out:
# 품목대분류명
# e상품/서비스    12109299
# 가구           135554
# 건강           890922
# 기타           291332
# 뷰티           801723
# 생활          1604069
# 식품          2904327
# 여가/스포츠      2388971
# 의류           901036
# 인테리어         334541
# 전자           959948
# 출산/육아       1397660
# 패션잡화         704807
# Name: 매출건수, dtype: int64

# %%
df_L_C = pd.DataFrame(grouped_L_C);df_L_C
# Out:
#              매출건수
# 품목대분류명
# e상품/서비스  12109299
# 가구         135554
# 건강         890922
# 기타         291332
# 뷰티         801723
# 생활        1604069
# 식품        2904327
# 여가/스포츠    2388971
# 의류         901036
# 인테리어       334541
# 전자         959948
# 출산/육아     1397660
# 패션잡화       704807

# %%
df_L_C.reset_index(inplace=True)
df_L_C.rename(columns={'품목대분류명':'largecategory', '매출건수':'Total'}, inplace=True)
df_L_C
# Out:
#    largecategory     Total
# 0        e상품/서비스  12109299
# 1             가구    135554
# 2             건강    890922
# 3             기타    291332
# 4             뷰티    801723
# 5             생활   1604069
# 6             식품   2904327
# 7         여가/스포츠   2388971
# 8             의류    901036
# 9           인테리어    334541
# 10            전자    959948
# 11         출산/육아   1397660
# 12          패션잡화    704807

# %%
sns.barplot(x = 'largecategory', y = 'Total', data = df_L_C)
# Out:
# <AxesSubplot:xlabel='largecategory', ylabel='Total'>

# %%
data_L_M.set_index('기준년월', inplace=True)

# %%
data_L_M
# Out:
#          품목대분류명     매출금액
# 기준년월
# 201903       의류   782521
# 201903  e상품/서비스   963789
# 201903    출산/육아   924309
# 201903  e상품/서비스  1089360
# 201903       생활  1656740
# ...         ...      ...
# 202103   여가/스포츠  1411368
# 202103  e상품/서비스  1386040
# 202103     패션잡화   390818
# 202103       식품   327592
# 202103  e상품/서비스   926404
#
# [519297 rows x 2 columns]

# %%
df_L_M1903 = data_L_M.loc[201903]
df_L_M1909 = data_L_M.loc[201909]
df_L_M2003 = data_L_M.loc[202003]
df_L_M2009 = data_L_M.loc[202009]
df_L_M2103 = data_L_M.loc[202103]

# %%
dfset = [df_L_M1903, df_L_M1909, df_L_M2003, df_L_M2009, df_L_M2103]
for df in dfset:
    df.rename(columns={'매출금액':'매출합계'}, inplace = True)
    df.reset_index(inplace=True)
    df.rename(columns= {'품목대분류명' : 'largecategory', '매출합계' : 'Total_Money'}, inplace= True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_L_M1903
# Out:
#          기준년월 largecategory  Total_Money
# 0      201903            의류       782521
# 1      201903       e상품/서비스       963789
# 2      201903         출산/육아       924309
# 3      201903       e상품/서비스      1089360
# 4      201903            생활      1656740
# ...       ...           ...          ...
# 68256  201903            의류      1260455
# 68257  201903         출산/육아      2894378
# 68258  201903       e상품/서비스     13276210
# 68259  201903        여가/스포츠       223538
# 68260  201903            의류       835484
#
# [68261 rows x 3 columns]

# %%
sns.barplot(x = 'largecategory', y = 'Total_Money', data = df_L_M1903)
# Out:
# <AxesSubplot:xlabel='largecategory', ylabel='Total_Money'>

# %%
sns.barplot(x = 'largecategory', y = 'Total_Money', data = df_L_M1903)
# Out:
# <AxesSubplot:xlabel='largecategory', ylabel='Total_Money'>

# %%
sns.barplot(x = 'largecategory', y = 'Total_Money', data = df_L_M2003)
# Out:
# <AxesSubplot:xlabel='largecategory', ylabel='Total_Money'>

# %%
sns.barplot(x = 'largecategory', y = 'Total_Money', data = df_L_M2009)
# Out:
# <AxesSubplot:xlabel='largecategory', ylabel='Total_Money'>

# %%
sns.barplot(x = 'largecategory', y = 'Total_Money', data = df_L_M2103)
# Out:
# <AxesSubplot:xlabel='largecategory', ylabel='Total_Money'>

# %%
data_df
# Out:
#           기준년월  품목대분류코드   품목대분류명  품목중분류코드   품목중분류명  성별      연령   가구생애주기  \
# 0       201903       10       의류     1010     여성의류  여성     40대  초중고자녀가구
# 1       201903       21  e상품/서비스     2110   o2o서비스  여성     20대  신혼영유아가구
# 2       201903       19    출산/육아     1913  육아용품서비스  여성     30대  신혼영유아가구
# 3       201903       21  e상품/서비스     2111  e머니/상품권  여성     30대  신혼영유아가구
# 4       201903       17       생활     1710     생활용품  여성     30대  신혼영유아가구
# ...        ...      ...      ...      ...      ...  ..     ...      ...
# 519292  202103       20   여가/스포츠     2013       여행  여성     30대     1인가구
# 519293  202103       21  e상품/서비스     2110   o2o서비스  남성     30대     1인가구
# 519294  202103       11     패션잡화     1113   시계/주얼리  여성     30대  신혼영유아가구
# 519295  202103       16       식품     1610     가공식품  남성     40대  초중고자녀가구
# 519296  202103       21  e상품/서비스     2110   o2o서비스  여성  60대 이상     노인가구
#
#        고객소재지_광역시도 고객소재지_시군구 고객소재지_읍면동     매출금액  매출건수
# 0           서울특별시       구로구        궁동   782521    13
# 1           서울특별시       구로구        궁동   963789    29
# 2           서울특별시       구로구        궁동   924309    46
# 3           서울특별시       구로구        궁동  1089360    54
# 4           서울특별시       구로구        궁동  1656740    58
# ...           ...       ...       ...      ...   ...
# 519292      서울특별시      영등포구    영등포동7가  1411368     7
# 519293      서울특별시      영등포구    영등포동7가  1386040    63
# 519294      서울특별시      영등포구    영등포동7가   390818     7
# 519295      서울특별시      영등포구    영등포동7가   327592     7
# 519296      서울특별시      영등포구    영등포동8가   926404    10
#
# [519297 rows x 13 columns]

# %%
dfLM = data_df[['기준년월', '품목대분류명','품목중분류명','매출금액']]
dfLM
# Out:
#           기준년월   품목대분류명   품목중분류명     매출금액
# 0       201903       의류     여성의류   782521
# 1       201903  e상품/서비스   o2o서비스   963789
# 2       201903    출산/육아  육아용품서비스   924309
# 3       201903  e상품/서비스  e머니/상품권  1089360
# 4       201903       생활     생활용품  1656740
# ...        ...      ...      ...      ...
# 519292  202103   여가/스포츠       여행  1411368
# 519293  202103  e상품/서비스   o2o서비스  1386040
# 519294  202103     패션잡화   시계/주얼리   390818
# 519295  202103       식품     가공식품   327592
# 519296  202103  e상품/서비스   o2o서비스   926404
#
# [519297 rows x 4 columns]

# %%
def get_barplot_M(category):
    dfLM_bar = dfLM[dfLM['품목대분류명'] == category]
    sns.barplot(x = '품목중분류명', y = '매출금액', hue = '기준년월', data = dfLM_bar)

# %%
get_barplot_M('전자')

# %%
get_barplot_M('여가/스포츠')

# %%
get_barplot_M('식품')

# %%
get_barplot_M('e상품/서비스')

# %%
def get_barplot_C(category):
    dfLC = data_df[['기준년월', '품목대분류명','품목중분류명','매출건수']]
    dfLC
    dfLC_bar = dfLC[dfLC['품목대분류명'] == category]
    sns.barplot(x = '품목중분류명', y = '매출건수', hue = '기준년월', data = dfLC_bar)

# %%
get_barplot_C('전자')

# %%
get_barplot_C('e상품/서비스')

# %%
get_barplot_C('여가/스포츠')

# %%
get_barplot_C('식품')
